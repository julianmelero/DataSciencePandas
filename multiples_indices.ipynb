# %%
import pandas as pd
import numpy as np

# %%
df_population = pd.read_csv('population.csv',skiprows=4)
df_population
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54208.0      55434.0      56234.0      56699.0
# ...

# %%
idx_filtro = df_population['Country Name'].isin(['Spain', 'Colombia'])
idx_filtro
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 261    False
# 262    False
# 263    False
# 264    False
# 265    False
# Name: Country Name, Length: 266, dtype: bool

# %%
df_sample = df_population[idx_filtro]
df_sample
# Out:
#    Country Name Country Code     Indicator Name Indicator Code        1960  \
# 45     Colombia          COL  Population, total    SP.POP.TOTL  16057714.0
# 70        Spain          ESP  Population, total    SP.POP.TOTL  30455000.0
#
#           1961        1962        1963        1964        1965  ...  \
# 45  16567817.0  17092919.0  17629978.0  18175187.0  18725242.0  ...
# 70  30739250.0  31023366.0  31296651.0  31609195.0  31954292.0  ...
#
#           2012        2013        2014        2015        2016        2017  \
# 45  46075721.0  46495492.0  46967706.0  47520667.0  48175048.0  48909844.0
# 70  46773055.0  46620045.0  46480882.0  46444832.0  46484062.0  46593236.0
#
#           2018        2019        2020  Unnamed: 65
# 45  49661056.0  50339443.0  50882884.0          NaN
# 70  46797754.0  47133521.0  47351567.0          NaN
#
# [2 rows x 66 columns]

# %%
#df_sample.set_index(['Country Name','2020']).sort_index()
df_sample = df_sample.set_index(['Country Name'])
df_sample
# Out:
#                         Country Code     Indicator Name Indicator Code  \
# Country Name 2020
# Colombia     50882884.0          COL  Population, total    SP.POP.TOTL
# Spain        47351567.0          ESP  Population, total    SP.POP.TOTL
#
#                                1960        1961        1962        1963  \
# Country Name 2020
# Colombia     50882884.0  16057714.0  16567817.0  17092919.0  17629978.0
# Spain        47351567.0  30455000.0  30739250.0  31023366.0  31296651.0
#
#                                1964        1965        1966  ...        2011  \
# Country Name 2020                                            ...
# Colombia     50882884.0  18175187.0  18725242.0  19279734.0  ...  45662747.0
# Spain        47351567.0  31609195.0  31954292.0  32283194.0  ...  46742697.0
#
#                                2012        2013        2014        2015  \
# Country Name 2020
# Colombia     50882884.0  46075721.0  46495492.0  46967706.0  47520667.0
# ...

# %%
df_sample.loc['Spain',:]
# Out:
#            Country Code     Indicator Name Indicator Code        1960  \
# 2020
# 47351567.0          ESP  Population, total    SP.POP.TOTL  30455000.0
#
#                   1961        1962        1963        1964        1965  \
# 2020
# 47351567.0  30739250.0  31023366.0  31296651.0  31609195.0  31954292.0
#
#                   1966  ...        2011        2012        2013        2014  \
# 2020                    ...
# 47351567.0  32283194.0  ...  46742697.0  46773055.0  46620045.0  46480882.0
#
#                   2015        2016        2017        2018        2019  \
# 2020
# 47351567.0  46444832.0  46484062.0  46593236.0  46797754.0  47133521.0
#
#             Unnamed: 65
# 2020
# 47351567.0          NaN
#
# [1 rows x 64 columns]

# %%
df_sample.xs(['Spain'])
# Out:
# /tmp/ipykernel_475/2739930638.py:1: FutureWarning: Passing lists as key for xs is deprecated and will be removed in a future version. Pass key as a tuple instead.
#   df_sample.xs(['Spain'])
#            Country Code     Indicator Name Indicator Code        1960  \
# 2020
# 47351567.0          ESP  Population, total    SP.POP.TOTL  30455000.0
#
#                   1961        1962        1963        1964        1965  \
# 2020
# 47351567.0  30739250.0  31023366.0  31296651.0  31609195.0  31954292.0
#
#                   1966  ...        2011        2012        2013        2014  \
# 2020                    ...
# 47351567.0  32283194.0  ...  46742697.0  46773055.0  46620045.0  46480882.0
#
#                   2015        2016        2017        2018        2019  \
# 2020
# 47351567.0  46444832.0  46484062.0  46593236.0  46797754.0  47133521.0
#
#             Unnamed: 65
# 2020
# 47351567.0          NaN
#
# [1 rows x 64 columns]

# %%
df_sample.index
df_sample.unstack(level=-1,fill_value='Year')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_475/819036900.py in <module>
#       1 df_sample.index
# ----> 2 df_sample.unstack[4,:]
#
# TypeError: 'method' object is not subscriptable
