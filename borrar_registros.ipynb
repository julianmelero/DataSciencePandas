# %% [markdown]
# # Borrado de registros

# %%
import pandas as pd

# %%
df_meteorites = pd.read_csv('Meteorite_Landings.csv')

# %%
df_meteorites['zeros'] = 0

# %% [markdown]
# ## Borrado de columna

# %%
df_meteorites.drop(['zeros'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1699/1643257859.py in <module>
# ----> 1 df_meteorites.drop(['zeros'], axis=1, inplace=True)
#       2 df_meteorites.head
#
# ~/develop/pandas/env-pandas/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/develop/pandas/env-pandas/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df_meteorites.head(5)
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %% [markdown]
# ## Borrado de filas

# %%
df_meteorites.drop([0,2,4,6]).head(10)
# Out:
#                 name   id nametype      recclass  mass (g)  fall  \
# 1             Aarhus    2    Valid            H6     720.0  Fell
# 3           Acapulco   10    Valid   Acapulcoite    1914.0  Fell
# 5           Adhi Kot  379    Valid           EH4    4239.0  Fell
# 7               Agen  392    Valid            H5   30000.0  Fell
# 8             Aguada  398    Valid            L6    1620.0  Fell
# 9      Aguila Blanca  417    Valid             L    1440.0  Fell
# 10  Aioun el Atrouss  423    Valid  Diogenite-pm    1000.0  Fell
# 11               Aïr  424    Valid            L6   24000.0  Fell
# 12   Aire-sur-la-Lys  425    Valid       Unknown       NaN  Fell
# 13             Akaba  426    Valid            L6     779.0  Fell
#
#                       year    reclat   reclong           GeoLocation
# 1   01/01/1951 12:00:00 AM  56.18333  10.23333  (56.18333, 10.23333)
# 3   01/01/1976 12:00:00 AM  16.88333 -99.90000     (16.88333, -99.9)
# ...

# %%
df_meteorites.drop(columns=['id', 'recclass'], index=[0,2,4,6]).head(10)
# Out:
#                 name nametype  mass (g)  fall                    year  \
# 1             Aarhus    Valid     720.0  Fell  01/01/1951 12:00:00 AM
# 3           Acapulco    Valid    1914.0  Fell  01/01/1976 12:00:00 AM
# 5           Adhi Kot    Valid    4239.0  Fell  01/01/1919 12:00:00 AM
# 7               Agen    Valid   30000.0  Fell  01/01/1814 12:00:00 AM
# 8             Aguada    Valid    1620.0  Fell  01/01/1930 12:00:00 AM
# 9      Aguila Blanca    Valid    1440.0  Fell  01/01/1920 12:00:00 AM
# 10  Aioun el Atrouss    Valid    1000.0  Fell  01/01/1974 12:00:00 AM
# 11               Aïr    Valid   24000.0  Fell  01/01/1925 12:00:00 AM
# 12   Aire-sur-la-Lys    Valid       NaN  Fell  01/01/1769 12:00:00 AM
# 13             Akaba    Valid     779.0  Fell  01/01/1949 12:00:00 AM
#
#       reclat   reclong           GeoLocation
# 1   56.18333  10.23333  (56.18333, 10.23333)
# 3   16.88333 -99.90000     (16.88333, -99.9)
# 5   32.10000  71.80000          (32.1, 71.8)
# ...

# %% [markdown]
# ## Modificar
# Con deep hacmos que el original no se modifique, pero sí la copia

# %%
new_df = df_meteorites.copy(deep=True)
new_df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# ...
